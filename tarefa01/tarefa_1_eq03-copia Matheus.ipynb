# %% [markdown]
# # Testando Spark

# %%
import pyspark
import pandas as pd
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import desc
import time

# %%
SparkContext.stop(sc)

# %%
def initialize_NewSparkContext(memory_fraction, message_maxSize, executor_cores, parallelism):
    conf = pyspark.SparkConf()
    conf.set("spark.storage.memoryFraction", "0.5")
    conf.set('spark.rpc.message.maxSize', '300')
    conf.set('spark.executor.cores', '5')
    conf.set('spark.default.parallelism','50')
    return pyspark.SparkContext(master = "spark://node5:7077", appName='testando Spark', conf=conf)


def calculate_join_time(df, dictionary):
    start = time.time()
    df_copy = df.alias("df_copy")
    new_df = df.join(df_copy, df.NUMERODN == df_copy.NUMERODN, how='left')
    end = time.time()

    dictionary['time_to_run_join'].append(end - start)
    

def calculate_groubyAndSort_time(df, dictionary):
    start = time.time()
    df_copy = df.alias("df_copy")
    new_df = df.join(df_copy, df.NUMERODN == df_copy.NUMERODN, how='left')
    end = time.time()

    dictionary['time_to_run_groubySort'].append(end - start)

    
def calculate_count_time(df, dictionary):
    start = time.time()
    df.count()
    end = time.time()
    dictionary['time_to_run_count'].append(end - start)

# %%
memory_fraction_list = ["0.5","0.8"]
message_maxSize_list = ['300','500']
executor_cores_list = ['5','3','1']
parallelism_list =  ['50','500']

result_data = {
                'experiment_block':[],
                'experiment_turn': [],
                'memory_fraction': [],
                'message_maxSize': [],
                'executor_cores': [],
                'parallelism': [],
                'time_to_run_join': [],
                'time_to_run_groubySort': [],  
                'time_to_run_count': [],  
            }

turn = 0
for memory_fraction in memory_fraction_list:
    for message_maxSize in message_maxSize_list:
        for executor_cores in executor_cores_list:
            for parallelism in parallelism_list:
                turn = turn + 1
                sc.stop()
                sc = initialize_NewSparkContext(memory_fraction, message_maxSize, executor_cores, parallelism)
                spark = SparkSession(sc)
                df = spark.read.csv('/home/bigdata/repos/fundamentos-big-data/codes/DNPBA2017.csv', header=True)
                
#                 print(sc.getConf().getAll())
                experiment_turns = 3
                for i in range(1,experiment_turns+1):
                    result_data['experiment_block'].append('Experiment Block: ' + str(turn))
                    result_data['experiment_turn'].append('Experiment turn: ' + str(i))
                                       
                    calculate_join_time(df, result_data)
                    calculate_groubyAndSort_time(df, result_data)
                    calculate_count_time(df, result_data)

                    result_data['memory_fraction'].append(memory_fraction)
                    result_data['message_maxSize'].append(message_maxSize)
                    result_data['executor_cores'].append(executor_cores)
                    result_data['parallelism'].append(parallelism)

# %%
df_result= pd.DataFrame(result_data)
df_result['total_time'] = df_result['time_to_run_join'] + df_result['time_to_run_groubySort'] +  df_result['time_to_run_count']
df_result.sort_values(by=['total_time']).head(50)
# Out:
#         experiment_block     experiment_turn memory_fraction message_maxSize  \
# 35  Experiment Block: 12  Experiment turn: 3             0.5             500
# 11   Experiment Block: 4  Experiment turn: 3             0.5             300
# 68  Experiment Block: 23  Experiment turn: 3             0.8             500
# 5    Experiment Block: 2  Experiment turn: 3             0.5             300
# 14   Experiment Block: 5  Experiment turn: 3             0.5             300
# 53  Experiment Block: 18  Experiment turn: 3             0.8             300
# 47  Experiment Block: 16  Experiment turn: 3             0.8             300
# 32  Experiment Block: 11  Experiment turn: 3             0.5             500
# 8    Experiment Block: 3  Experiment turn: 3             0.5             300
# 56  Experiment Block: 19  Experiment turn: 3             0.8             500
# 26   Experiment Block: 9  Experiment turn: 3             0.5             500
# 23   Experiment Block: 8  Experiment turn: 3             0.5             500
# 17   Experiment Block: 6  Experiment turn: 3             0.5             300
# 41              5         500          0.029995                0.060845
# 25              3          50          0.027724                0.027104
# 37              5          50          0.030187                0.027929
# 22              5         500          0.028367                0.031329
# 55              5          50          0.030972                0.029500
# 40              5         500          0.036389                0.029809
# 52              1         500          0.029119                0.027906
# 7               3          50          0.046006                0.030425
# 49              1          50          0.030764                0.056835
# 43              3          50          0.033350                0.032525
# 46              3         500          0.031032                0.029724
# 1               5          50          0.029103                0.027899
# 42              3          50          0.032477                0.028050
# 21              5         500          0.030576                0.026298
#
#     time_to_run_count  total_time
# 35           0.161180    0.214309
# 11           0.166204    0.219739
# 68           0.165311    0.221734
# 5            0.166465    0.222708
# 14           0.166927    0.222950
# 53           0.167509    0.225180
# 47           0.176199    0.234106
# 32           0.182362    0.237062
# 8            0.182648    0.238643
# 56           0.181616    0.242430
# 26           0.192001    0.247711
# 23           0.193248    0.248706
# 17           0.193696    0.248945
# 20           0.189145    0.250331
# 59           0.193364    0.251480
# 62           0.195969    0.252034
# 44           0.195800    0.254571
# 71           0.197676    0.254676
# 50           0.200194    0.258041
# 2            0.200861    0.258947
# 19           0.201960    0.260746
# 29           0.206609    0.262160
# 34           0.216017    0.269663
# 28           0.211923    0.270032
# 38           0.216050    0.270078
# 65           0.215150    0.273187
# 70           0.215816    0.274082
# 61           0.220091    0.276911
# 64           0.224612    0.280890
# 16           0.231874    0.285897
# 13           0.232007    0.286163
# 4            0.227072    0.287294
# 10           0.233312    0.287661
# 67           0.226376    0.287677
# 31           0.236200    0.288767
# 58           0.219232    0.288783
# 41           0.198152    0.288992
# 25           0.234565    0.289393
# 37           0.233284    0.291400
# 22           0.240899    0.300596
# 55           0.242882    0.303354
# 40           0.240616    0.306813
# 52           0.254280    0.311304
# 7            0.235335    0.311766
# 49           0.232279    0.319877
# 43           0.259058    0.324934
# 46           0.271603    0.332359
# 1            0.281200    0.338201
# 42           0.544683    0.605210
# 21           0.559237    0.616112

# %%
df_result
# Out:
#         experiment_block     experiment_turn memory_fraction message_maxSize  \
# 0    Experiment Block: 1  Experiment turn: 1             0.5             300
# 1    Experiment Block: 1  Experiment turn: 2             0.5             300
# 2    Experiment Block: 1  Experiment turn: 3             0.5             300
# 3    Experiment Block: 2  Experiment turn: 1             0.5             300
# 4    Experiment Block: 2  Experiment turn: 2             0.5             300
# ..                   ...                 ...             ...             ...
# 67  Experiment Block: 23  Experiment turn: 2             0.8             500
# 68  Experiment Block: 23  Experiment turn: 3             0.8             500
# 69  Experiment Block: 24  Experiment turn: 1             0.8             500
# 70  Experiment Block: 24  Experiment turn: 2             0.8             500
# 71  Experiment Block: 24  Experiment turn: 3             0.8             500
#
#    executor_cores parallelism  time_to_run_join  time_to_run_groubySort  \
# 0               5          50          0.033102                0.029054
# 1               5          50          0.029103                0.027899
# 2               5          50          0.029410                0.028676
# 3               5         500          0.030464                0.027407
# 4               5         500          0.030718                0.029504
# ..            ...         ...               ...                     ...
# 67              1          50          0.031355                0.029947
# 68              1          50          0.028579                0.027845
# 69              1         500          0.038094                0.029830
# 70              1         500          0.029675                0.028590
# 71              1         500          0.028628                0.028372
#
#     time_to_run_count  total_time
# 0            0.603614    0.665769
# 1            0.281200    0.338201
# 2            0.200861    0.258947
# 3            0.597176    0.655047
# 4            0.227072    0.287294
# ..                ...         ...
# 67           0.226376    0.287677
# 68           0.165311    0.221734
# 69           0.602646    0.670570
# 70           0.215816    0.274082
# 71           0.197676    0.254676
#
# [72 rows x 10 columns]

# %%
df_result.to_csv('Resultado_Tarefa01_eq03.csv', index = False)
